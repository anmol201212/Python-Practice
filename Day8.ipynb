# %% [markdown]
# # Dictionary

# %%
person = {
    'first_name':'Asabeneh',
    'last_name':'Yetayeh',
    'age':250,
    'country':'Finland',
    'is_marred':True,
    'skills':['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address':{
        'street':'Space street',
        'zipcode':'02210'
    }
    }
person
# Out:
# {'first_name': 'Asabeneh',
#  'last_name': 'Yetayeh',
#  'age': 250,
#  'country': 'Finland',
#  'is_marred': True,
#  'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
#  'address': {'street': 'Space street', 'zipcode': '02210'}}

# %%
len(person)
# Out:
# 7

# %%
print(person['skills'][3])
person['skills']
# Out:
# MongoDB
# ['JavaScript', 'React', 'Node', 'MongoDB', 'Python']

# %%
print(person['xyz'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(person['xyz'])
#
# KeyError: 'xyz'

# %%
print(person.get('xyz'))
# Out:
# None

# %%
'country' in person
# Out:
# True

# %%
# pop(key): removes the item with the specified key name:
# popitem(): removes the last item
# del: removes an item with specified key name
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
dct.pop('key2')
print(dct)
dct.popitem()
print(dct)
del dct['key3']
print(dct)
# Out:
# {'key1': 'value1', 'key3': 'value3', 'key4': 'value4'}
# {'key1': 'value1', 'key3': 'value3'}
# {'key1': 'value1'}

# %%
# The items() method changes dictionary to a list of tuples.
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
print(dct.items())
print(list(dct.items()))
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3'), ('key4', 'value4')])
# [('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3'), ('key4', 'value4')]

# %%
# syntax
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
print(dct.clear()) # None
del dct
print(dct)
# Out:
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       1 # syntax
#       2 dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
#       3 print(dct.clear()) # None
#       4 del dct
# ----> 5 print(dct)
#
# NameError: name 'dct' is not defined

# %%
# syntax
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
dct_copy = dct.copy() # {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
dct_copy
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
print(dct.keys())
print(dct.values())
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4'])
# dict_values(['value1', 'value2', 'value3', 'value4'])

# %%
x = list(dct.keys())
x[1]
# Out:
# 'key2'

# %% [markdown]
# # Exercise
